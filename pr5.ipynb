# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('dark_background')
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16996\754560520.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv("archive(5)\weatherAUS.csv")
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_16996\1938526802.py:1: SyntaxWarning: invalid escape sequence '\w'
#   df=pd.read_csv("archive(5)\weatherAUS.csv")
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# ...

# %%
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
df.shape
# Out:
# (145460, 23)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
df=df.drop(["Evaporation","Sunshine","Cloud9am","Cloud3pm","Location","Date"],axis=1)
df.head()
# Out:
#    MinTemp  MaxTemp  Rainfall WindGustDir  WindGustSpeed WindDir9am  \
# 0     13.4     22.9       0.6           W           44.0          W
# 1      7.4     25.1       0.0         WNW           44.0        NNW
# 2     12.9     25.7       0.0         WSW           46.0          W
# 3      9.2     28.0       0.0          NE           24.0         SE
# 4     17.5     32.3       1.0           W           41.0        ENE
#
#   WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0        WNW          20.0          24.0         71.0         22.0
# 1        WSW           4.0          22.0         44.0         25.0
# 2        WSW          19.0          26.0         38.0         30.0
# 3          E          11.0           9.0         45.0         16.0
# 4         NW           7.0          20.0         82.0         33.0
#
#    Pressure9am  Pressure3pm  Temp9am  Temp3pm RainToday RainTomorrow
# 0       1007.7       1007.1     16.9     21.8        No           No
# ...

# %%
df=df.dropna(axis=0)
df.shape
# Out:
# (112925, 17)

# %%
df.columns
# Out:
# Index(['MinTemp', 'MaxTemp', 'Rainfall', 'WindGustDir', 'WindGustSpeed',
#        'WindDir9am', 'WindDir3pm', 'WindSpeed9am', 'WindSpeed3pm',
#        'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %%
"""from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['WindGustDir']=le.fit_transform(df['WindGustDir'])
df['WindDir9am']=le.fit_transform(df['WindDir9am'])
df['WindDir3am']=le.fit_transform(df['WindDir3am'])
df['RainToday']=le.fit_transform(df['RainToday'])
df['RainTomorrow']=le.fit_transform(df['RainTomorrow'])"""
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# Encode each column individually
df['WindGustDir'] = le.fit_transform(df['WindGustDir'])
df['WindDir9am'] = le.fit_transform(df['WindDir9am'])

# Check if 'WindDir3am' exists in the DataFrame before encoding
if 'WindDir3am' in df.columns:
    df['WindDir3am'] = le.fit_transform(df['WindDir3am'])

# Check if 'RainToday' exists in the DataFrame before encoding
if 'RainToday' in df.columns:
    df['RainToday'] = le.fit_transform(df['RainToday'])

# Check if 'RainTomorrow' exists in the DataFrame before encoding
if 'RainTomorrow' in df.columns:
    df['RainTomorrow'] = le.fit_transform(df['RainTomorrow'])

# %%
df.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  WindGustDir  WindGustSpeed  WindDir9am  \
# 0     13.4     22.9       0.6           13           44.0          13
# 1      7.4     25.1       0.0           14           44.0           6
# 2     12.9     25.7       0.0           15           46.0          13
# 3      9.2     28.0       0.0            4           24.0           9
# 4     17.5     32.3       1.0           13           41.0           1
#
#   WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0        WNW          20.0          24.0         71.0         22.0
# 1        WSW           4.0          22.0         44.0         25.0
# 2        WSW          19.0          26.0         38.0         30.0
# 3          E          11.0           9.0         45.0         16.0
# 4         NW           7.0          20.0         82.0         33.0
#
#    Pressure9am  Pressure3pm  Temp9am  Temp3pm RainToday RainTomorrow
# 0       1007.7       1007.1     16.9     21.8        No           No
# ...

# %%
x=df.drop(['RainTomorrow'],axis=1)
y=df['RainTomorrow']

# %%
x.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  WindGustDir  WindGustSpeed  WindDir9am  \
# 0     13.4     22.9       0.6           13           44.0          13
# 1      7.4     25.1       0.0           14           44.0           6
# 2     12.9     25.7       0.0           15           46.0          13
# 3      9.2     28.0       0.0            4           24.0           9
# 4     17.5     32.3       1.0           13           41.0           1
#
#   WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0        WNW          20.0          24.0         71.0         22.0
# 1        WSW           4.0          22.0         44.0         25.0
# 2        WSW          19.0          26.0         38.0         30.0
# 3          E          11.0           9.0         45.0         16.0
# 4         NW           7.0          20.0         82.0         33.0
#
#    Pressure9am  Pressure3pm  Temp9am  Temp3pm RainToday
# 0       1007.7       1007.1     16.9     21.8        No
# ...

# %%
plt.figure(figsize= (8,8))
sns.scatterplot(x = 'MaxTemp', y = 'MinTemp', hue = 'RainTomorrow', palette = 'inferno', data = df)
# Out:
# <Axes: xlabel='MaxTemp', ylabel='MinTemp'>

# %%
plt.figure(figsize=(8, 8))  # Corrected the parameter name to 'figsize'
sns.scatterplot(x='Humidity9am', y='Temp9am', hue='RainTomorrow', palette='inferno', data=df)  # Corrected 'RainTomorrow'
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
le = LabelEncoder()

# Encode only existing columns
if 'WindDir3am' in df.columns:
    df['WindDir3am'] = le.fit_transform(df['WindDir3am'])

# Verify and encode other columns
# You can follow the same approach for other columns like 'RainToday', 'RainTomorrow', etc.

# Drop non-numeric columns if any
df_numeric = df.select_dtypes(include='number')

# Plot heatmap of correlation matrix
plt.figure(figsize=(8, 8))
sns.heatmap(df_numeric.corr())
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)
predictions = dt.predict(x_test)
print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
print(accuracy_score(y_test,predictions))
# Out:
# [[15046  2497]
#  [ 2312  2730]]
#               precision    recall  f1-score   support
#
#           No       0.87      0.86      0.86     17543
#          Yes       0.52      0.54      0.53      5042
#
#     accuracy                           0.79     22585
#    macro avg       0.69      0.70      0.70     22585
# weighted avg       0.79      0.79      0.79     22585
#
# 0.7870710648660616
# ...

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

# Create Decision Tree classifier
dt = DecisionTreeClassifier()

# Fit the classifier
dt.fit(x_train, y_train)

# Plot decision tree
plt.figure(figsize=(20,10))  # Set the figure size
plot_tree(dt, filled=True, feature_names=x_train.columns, class_names=True)  # Plot the tree
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Iterate through each column in x_test
for column in x_test.columns:
    # Check if the column dtype is object (indicating categorical variable)
    if x_test[column].dtype == 'object':
        # Use LabelEncoder to transform categorical variables
        x_test[column] = label_encoder.fit_transform(x_test[column])

# Make predictions
predictions = rf.predict(x_test)

# Evaluate the model
print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
print(accuracy_score(y_test, predictions))
# Out:
# [[16679   864]
#  [ 2409  2633]]
#               precision    recall  f1-score   support
#
#           No       0.87      0.95      0.91     17543
#          Yes       0.75      0.52      0.62      5042
#
#     accuracy                           0.86     22585
#    macro avg       0.81      0.74      0.76     22585
# weighted avg       0.85      0.86      0.85     22585
#
# 0.8550808058445871
